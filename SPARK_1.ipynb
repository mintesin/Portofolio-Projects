# %% [markdown]
# <a href="https://colab.research.google.com/github/mintesin/Projects/blob/main/SPARK_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('Dataframe').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://ip-10-0-200-181:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Dataframe</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
#reading the dataset
data=spark.read.option("header","true").csv('feature_matrix.csv',inferSchema=True)

# %%
data.show()
# Out:
# +---+---------+------------------+-----+------------------+--------------------+--------------------+---+------+------+-------+
# |_c0|Longitude|          Latitude|Speed|          Distance|          Distance_x|          Distance_y|PCI|PCI_64|PCI_65|PCI_302|
# +---+---------+------------------+-----+------------------+--------------------+--------------------+---+------+------+-------+
# |  0|12.520112|         55.780073|21.51|0.5530644296850808|-0.00459719999999...|-0.00336900000000...| 64|     1|     0|      0|
# |  1|12.520119|         55.780071|20.93| 0.553103502794036|-0.00459920000000...|-0.00336200000000...| 64|     1|     0|      0|
# |  2|12.520127|          55.78007|20.36|0.5530163642392476|-0.00460019999999...|-0.00335399999999...| 64|     1|     0|      0|
# |  3|12.520135| 55.78006800000001|19.78| 0.553032643909539|-0.00460219999999...|-0.00334600000000...| 64|     1|     0|      0|
# ...

# %%
#getting the info or writing the schema
data.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- Longitude: double (nullable = true)
#  |-- Latitude: double (nullable = true)
#  |-- Speed: double (nullable = true)
#  |-- Distance: double (nullable = true)
#  |-- Distance_x: double (nullable = true)
#  |-- Distance_y: double (nullable = true)
#  |-- PCI: integer (nullable = true)
#  |-- PCI_64: integer (nullable = true)
#  |-- PCI_65: integer (nullable = true)
#  |-- PCI_302: integer (nullable = true)

# %% [markdown]
# **ANOTHER WAY OF READING DATASET**

# %%
data_2=spark.read.csv('feature_matrix.csv',header=True,inferSchema=True)
data_2.show()
# Out:
# +---+---------+------------------+-----+------------------+--------------------+--------------------+---+------+------+-------+
# |_c0|Longitude|          Latitude|Speed|          Distance|          Distance_x|          Distance_y|PCI|PCI_64|PCI_65|PCI_302|
# +---+---------+------------------+-----+------------------+--------------------+--------------------+---+------+------+-------+
# |  0|12.520112|         55.780073|21.51|0.5530644296850808|-0.00459719999999...|-0.00336900000000...| 64|     1|     0|      0|
# |  1|12.520119|         55.780071|20.93| 0.553103502794036|-0.00459920000000...|-0.00336200000000...| 64|     1|     0|      0|
# |  2|12.520127|          55.78007|20.36|0.5530163642392476|-0.00460019999999...|-0.00335399999999...| 64|     1|     0|      0|
# |  3|12.520135| 55.78006800000001|19.78| 0.553032643909539|-0.00460219999999...|-0.00334600000000...| 64|     1|     0|      0|
# ...

# %%
data_2.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- Longitude: double (nullable = true)
#  |-- Latitude: double (nullable = true)
#  |-- Speed: double (nullable = true)
#  |-- Distance: double (nullable = true)
#  |-- Distance_x: double (nullable = true)
#  |-- Distance_y: double (nullable = true)
#  |-- PCI: integer (nullable = true)
#  |-- PCI_64: integer (nullable = true)
#  |-- PCI_65: integer (nullable = true)
#  |-- PCI_302: integer (nullable = true)

# %%
type(data_2)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
data_2.columns
# Out:
# ['_c0',
#  'Longitude',
#  'Latitude',
#  'Speed',
#  'Distance',
#  'Distance_x',
#  'Distance_y',
#  'PCI',
#  'PCI_64',
#  'PCI_65',
#  'PCI_302']

# %%
data_2.head(13)
# Out:
# [Row(_c0=0, Longitude=12.520112, Latitude=55.780073, Speed=21.51, Distance=0.5530644296850808, Distance_x=-0.004597199999999191, Distance_y=-0.0033690000000010656, PCI=64, PCI_64=1, PCI_65=0, PCI_302=0),
#  Row(_c0=1, Longitude=12.520119, Latitude=55.780071, Speed=20.93, Distance=0.553103502794036, Distance_x=-0.004599200000001247, Distance_y=-0.0033620000000009753, PCI=64, PCI_64=1, PCI_65=0, PCI_302=0),
#  Row(_c0=2, Longitude=12.520127, Latitude=55.78007, Speed=20.36, Distance=0.5530163642392476, Distance_x=-0.004600199999998722, Distance_y=-0.003353999999999857, PCI=64, PCI_64=1, PCI_65=0, PCI_302=0),
#  Row(_c0=3, Longitude=12.520135, Latitude=55.78006800000001, Speed=19.78, Distance=0.553032643909539, Distance_x=-0.0046021999999936725, Distance_y=-0.0033460000000005152, PCI=64, PCI_64=1, PCI_65=0, PCI_302=0),
# ...

# %%
data_2.tail(13)
# Out:
# [Row(_c0=57573, Longitude=12.518176, Latitude=55.780575, Speed=24.0, Distance=0.5635527683187204, Distance_x=-0.004095200000001853, Distance_y=-0.005304999999999893, PCI=302, PCI_64=0, PCI_65=0, PCI_302=1),
#  Row(_c0=57574, Longitude=12.518172, Latitude=55.78056899999999, Speed=23.39, Distance=0.5642395581107388, Distance_x=-0.004101200000008021, Distance_y=-0.005309000000000452, PCI=302, PCI_64=0, PCI_65=0, PCI_302=1),
#  Row(_c0=57575, Longitude=12.519316, Latitude=55.780908, Speed=39.34, Distance=0.4929331387378337, Distance_x=-0.0037622000000041567, Distance_y=-0.004165000000000418, PCI=302, PCI_64=0, PCI_65=0, PCI_302=1),
#  Row(_c0=57576, Longitude=12.519321, Latitude=55.780917, Speed=39.51, Distance=0.4919180682442706, Distance_x=-0.0037531999999984578, Distance_y=-0.004160000000000608, PCI=302, PCI_64=0, PCI_65=0, PCI_302=1),
# ...

# %% [markdown]
# Indexing,selecting column

# %%
data_2.select('Latitude','Longitude').show()
# Out:
# +------------------+---------+
# |          Latitude|Longitude|
# +------------------+---------+
# |         55.780073|12.520112|
# |         55.780071|12.520119|
# |          55.78007|12.520127|
# | 55.78006800000001|12.520135|
# |         55.780067|12.520142|
# |         55.780065| 12.52015|
# |         55.780064|12.520158|
# |         55.780062|12.520165|
# |         55.780061|12.520173|
# |         55.780059|12.520181|
# |         55.780058|12.520186|
# | 55.78005600000001|12.520193|
# |         55.780055|12.520198|
# |         55.780053|12.520204|
# | 55.78005200000001|12.520209|
# |          55.78005|12.520215|
# |         55.780048|12.520223|
# |         55.780046|12.520229|
# |         55.780045|12.520234|
# |55.780043000000006|12.520238|
# +------------------+---------+
# only showing top 20 rows

# %%
#check for the datatyps
data_2.dtypes
# Out:
# [('_c0', 'int'),
#  ('Longitude', 'double'),
#  ('Latitude', 'double'),
#  ('Speed', 'double'),
#  ('Distance', 'double'),
#  ('Distance_x', 'double'),
#  ('Distance_y', 'double'),
#  ('PCI', 'int'),
#  ('PCI_64', 'int'),
#  ('PCI_65', 'int'),
#  ('PCI_302', 'int')]

# %%
data_2.describe().show()
# Out:
# +-------+------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+------------------+-------------------+-------------------+------------------+
# |summary|               _c0|           Longitude|            Latitude|             Speed|            Distance|          Distance_x|          Distance_y|               PCI|             PCI_64|             PCI_65|           PCI_302|
# +-------+------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+------------------+-------------------+-------------------+------------------+
# |  count|             57586|               57586|               57586|             57586|               57586|               57586|               57586|             57586|              57586|              57586|             57586|
# ...

# %%
#add columnss
m=data_2.withColumn('Latitude_2',data_2['Latitude']+2)
m.show()
# Out:
# +---+---------+------------------+-----+------------------+--------------------+--------------------+---+------+------+-------+------------------+
# |_c0|Longitude|          Latitude|Speed|          Distance|          Distance_x|          Distance_y|PCI|PCI_64|PCI_65|PCI_302|        Latitude_2|
# +---+---------+------------------+-----+------------------+--------------------+--------------------+---+------+------+-------+------------------+
# |  0|12.520112|         55.780073|21.51|0.5530644296850808|-0.00459719999999...|-0.00336900000000...| 64|     1|     0|      0|         57.780073|
# |  1|12.520119|         55.780071|20.93| 0.553103502794036|-0.00459920000000...|-0.00336200000000...| 64|     1|     0|      0|         57.780071|
# |  2|12.520127|          55.78007|20.36|0.5530163642392476|-0.00460019999999...|-0.00335399999999...| 64|     1|     0|      0|          57.78007|
# ...

# %%
m.columns
# Out:
# ['_c0',
#  'Longitude',
#  'Latitude',
#  'Speed',
#  'Distance',
#  'Distance_x',
#  'Distance_y',
#  'PCI',
#  'PCI_64',
#  'PCI_65',
#  'PCI_302',
#  'Latitude_2']

# %%
#drop the columnss
m_2=m.drop('Latitude_2')
m_2.columns
# Out:
# ['_c0',
#  'Longitude',
#  'Latitude',
#  'Speed',
#  'Distance',
#  'Distance_x',
#  'Distance_y',
#  'PCI',
#  'PCI_64',
#  'PCI_65',
#  'PCI_302']

# %%
#renaming the 
g=m_2.withColumnRenamed('Longitude','Longitude_x')
g.columns
# Out:
# ['_c0',
#  'Longitude_x',
#  'Latitude',
#  'Speed',
#  'Distance',
#  'Distance_x',
#  'Distance_y',
#  'PCI',
#  'PCI_64',
#  'PCI_65',
#  'PCI_302']
